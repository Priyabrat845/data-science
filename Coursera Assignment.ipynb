# %% [markdown]
# # Data analysis with python .

# %% [markdown]
# *After we have collected data from different sources we can analyse our data,deal with the missing values by replacing it with mean or mode or any other methods or drop the missing value,do the data formating,correcting the datatypes etc.Below I have taken some examples on how to do analysis of the collected data and drop the missing values in our dataframe.*

# %% [markdown]
# ### import pandas to the jupyter notebook

# %%
import pandas as pd

# %% [markdown]
# ### create data frame by a sample data sets .

# %%
df=pd.read_csv('https://data.cityofchicago.org/resource/jcxq-k9xf.csv')

# %% [markdown]
# ### display the first 5 rows of the data frame to check wheter the values are added properly or not.

# %%
df.head()
# Out:
#     ca community_area_name  percent_of_housing_crowded  \
# 0  1.0         Rogers Park                         7.7
# 1  2.0          West Ridge                         7.8
# 2  3.0              Uptown                         3.8
# 3  4.0      Lincoln Square                         3.4
# 4  5.0        North Center                         0.3
#
#    percent_households_below_poverty  percent_aged_16_unemployed  \
# 0                              23.6                         8.7
# 1                              17.2                         8.8
# 2                              24.0                         8.9
# 3                              10.9                         8.2
# 4                               7.5                         5.2
#
#    percent_aged_25_without_high_school_diploma  \
# 0                                         18.2
# 1                                         20.8
# 2                                         11.8
# 3                                         13.4
# ...

# %% [markdown]
# ### use datafram.dtypes to know the datatypes of the columns.

# %%
df.dtypes
# Out:
# ca                                             float64
# community_area_name                             object
# percent_of_housing_crowded                     float64
# percent_households_below_poverty               float64
# percent_aged_16_unemployed                     float64
# percent_aged_25_without_high_school_diploma    float64
# percent_aged_under_18_or_over_64               float64
# per_capita_income_                               int64
# hardship_index                                 float64
# dtype: object

# %% [markdown]
# ### use dataframe.describe(include='all') to know the statistical summary of each column .

# %%
df.describe(include='all')
# Out:
#                ca community_area_name  percent_of_housing_crowded  \
# count   77.000000                  78                   78.000000
# unique        NaN                  78                         NaN
# top           NaN      Belmont Cragin                         NaN
# freq          NaN                   1                         NaN
# mean    39.000000                 NaN                    4.920513
# std     22.371857                 NaN                    3.658981
# min      1.000000                 NaN                    0.300000
# 25%     20.000000                 NaN                    2.325000
# 50%     39.000000                 NaN                    3.850000
# 75%     58.000000                 NaN                    6.800000
# max     77.000000                 NaN                   15.800000
#
#         percent_households_below_poverty  percent_aged_16_unemployed  \
# count                          78.000000                   78.000000
# ...

# %% [markdown]
# ### use dataframe.info to diplay the concise summary of the columns .

# %%
df.info
# Out:
# <bound method DataFrame.info of       ca     community_area_name  percent_of_housing_crowded  \
# 0    1.0             Rogers Park                         7.7
# 1    2.0              West Ridge                         7.8
# 2    3.0                  Uptown                         3.8
# 3    4.0          Lincoln Square                         3.4
# 4    5.0            North Center                         0.3
# 5    6.0               Lake View                         1.1
# 6    7.0            Lincoln Park                         0.8
# 7    8.0         Near North Side                         1.9
# 8    9.0             Edison Park                         1.1
# 9   10.0            Norwood Park                         2.0
# 10  11.0          Jefferson Park                         2.7
# 11  12.0             Forest Glen                         1.1
# 12  13.0              North Park                         3.9
# 13  14.0             Albany Park                        11.3
# ...

# %% [markdown]
# ### drop the missing values in the dataframe by dataframe.dropna(subset["column-name"],axis=0)---To delete rows having column value=0.

# %%
df.dropna(subset=["community_area_name"],axis=0)
# Out:
#       ca     community_area_name  percent_of_housing_crowded  \
# 0    1.0             Rogers Park                         7.7
# 1    2.0              West Ridge                         7.8
# 2    3.0                  Uptown                         3.8
# 3    4.0          Lincoln Square                         3.4
# 4    5.0            North Center                         0.3
# 5    6.0               Lake View                         1.1
# 6    7.0            Lincoln Park                         0.8
# 7    8.0         Near North Side                         1.9
# 8    9.0             Edison Park                         1.1
# 9   10.0            Norwood Park                         2.0
# 10  11.0          Jefferson Park                         2.7
# 11  12.0             Forest Glen                         1.1
# 12  13.0              North Park                         3.9
# 13  14.0             Albany Park                        11.3
# ...
